# %%
from qiskit import QuantumCircuit
from qiskit.visualization import plot_histogram

qc = QuantumCircuit(2)

# Create Bell state
qc.h(0)
qc.cx(0, 1)
qc.barrier()
qc.draw("mpl")

# %%
# encoding '11'
qc.x(0)
qc.z(0)
qc.barrier()

qc.draw("mpl")

# %%
# decoding
qc.cx(0, 1)
qc.h(0)
qc.measure_all()
qc.draw("mpl")

# %%
from qiskit import transpile
from qiskit_aer import AerSimulator
simulator = AerSimulator()
compiled_circuit = transpile(qc, simulator)
result=simulator.run(compiled_circuit, shots=4096).result()
counts = result.get_counts()
print("Measurement Results:", counts)

print("this mean that what sender want to send bit is 11 (3) through single Qubit")
# Out:
# Measurement Results: {'11': 4096}
# this mean that what sender want to send bit is 11 (3) through single Qubit
